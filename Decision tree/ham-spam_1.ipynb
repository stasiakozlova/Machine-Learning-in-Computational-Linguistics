# %%
from preprocessing import get_df, preprocess, get_most_common_ngrams, get_most_common_words

# %%
df = get_df()

# %%
preprocessed = preprocess(df.text)

# %%
# самые популярные ngram где n=2
get_most_common_ngrams(preprocessed)
# Out:
# [(('å', '£'), 303),
#  (('are', 'you'), 176),
#  (('i', 'am'), 142),
#  (('have', 'a'), 131),
#  (('you', 'are'), 129),
#  (('you', 'have'), 117),
#  (('i', 'will'), 117),
#  (('do', 'you'), 109),
#  (('in', 'the'), 99),
#  (('if', 'you'), 97),
#  (('i', 'have'), 92),
#  (('want', 'to'), 85),
#  (('will', 'be'), 83),
#  (('to', 'be'), 83),
#  (('to', 'get'), 82),
#  (('in', 'a'), 81),
#  (('i', 'was'), 80),
#  (('going', 'to'), 77),
#  (('a', 'å'), 73),
#  (('this', 'is'), 73),
#  (('i', 'can'), 72),
#  (('and', 'i'), 71),
#  (('but', 'i'), 71),
#  (('have', 'to'), 70),
#  (('if', 'u'), 69),
#  (('on', 'the'), 66),
#  (('for', 'the'), 62),
#  (('need', 'to'), 61),
#  (('call', 'now'), 59),
#  (('you', 'know'), 58),
#  (('go', 'to'), 58),
#  (('is', 'the'), 58),
#  (('i', 'need'), 57),
#  (('i', 'think'), 57),
#  (('i', 'want'), 56),
#  (('i', 'love'), 56),
#  (('you', 'want'), 56),
#  (('you', 'nannannan'), 55),
#  (('i', "don't"), 54),
#  (('have', 'won'), 54),
# ...

# %%
get_most_common_words(preprocessed)
# Out:
# [('i', 2339),
#  ('to', 2248),
#  ('nannannan', 2225),
#  ('you', 2099),
#  ('a', 1443),
#  ('the', 1337),
#  ('u', 1158),
#  ('and', 979),
#  ('is', 890),
#  ('in', 884),
#  ('my', 762),
#  ('me', 750),
#  ('for', 709),
#  ('your', 677),
#  ('of', 619),
#  ('it', 613),
#  ('have', 576),
#  ('call', 576),
#  ('on', 532),
#  ('that', 500),
#  ('are', 489),
#  ('so', 452),
#  ('now', 450),
#  ('but', 443),
#  ('not', 437),
#  ('or', 419),
#  ('can', 403),
#  ('do', 399),
#  ('at', 397),
#  ("i'm", 394),
#  ('ur', 391),
#  ('if', 389),
#  ('get', 387),
#  ('be', 385),
#  ('will', 384),
#  ('with', 379),
#  ('just', 372),
#  ('no', 361),
#  ('we', 354),
#  ('this', 331),
#  ('£', 329),
#  ('å', 303),
#  ('when', 295),
#  ('from', 285),
#  ('up', 284),
#  ('go', 279),
#  ('how', 274),
#  ('free', 273),
#  ('all', 269),
#  ('what', 263),
#  ('ok', 257),
#  ('know', 250),
#  ('out', 245),
#  ('like', 242),
#  ('good', 239),
#  ('got', 238),
#  ('was', 230),
#  ('come', 226),
# ...

# %%
# распределение длин текстов
lengths = preprocessed.apply(lambda words: len(words))
sorted_lengths = lengths.sort_values(ignore_index=True)
sorted_lengths.plot()
# Out:
# <AxesSubplot:>
